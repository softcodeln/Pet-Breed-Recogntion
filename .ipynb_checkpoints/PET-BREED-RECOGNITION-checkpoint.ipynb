# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
bs = 64

# %%
PETS = 'https://s3.amazonaws.com/fast-ai-imageclas/oxford-iiit-pet.tgz'

# %%
path = untar_data(URLs.PETS);
path
# Out:
# PosixPath('/tmp/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/tmp/.fastai/data/oxford-iiit-pet/models'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/'annotations';
path_img = path/'images';

# %%
fnames = get_image_files(path_img);
fnames[:7]
# Out:
# [PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/saint_bernard_115.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/pug_26.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/British_Shorthair_26.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/Ragdoll_160.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/scottish_terrier_93.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_198.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/pug_22.jpg')]

# %%
np.random.seed(42);
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path,fnames,pat,ds_tfms=get_transforms(),size=224,bs=bs).normalize(imagenet_stats)

# %%
data.show_batch(rows=3,figsize=(6,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %%
learn = cnn_learner(data,models.resnet34,metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.416646</td>
#       <td>0.343974</td>
#       <td>0.113667</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.632163</td>
#       <td>0.269980</td>
#       <td>0.087957</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.376891</td>
#       <td>0.232105</td>
#       <td>0.077131</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.282013</td>
#       <td>0.217267</td>
#       <td>0.073072</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()
len(data.valid_ds)==len(idxs)==len(losses)
# Out:
# True

# %%
interp.plot_top_losses(9,figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(15,12),dpi=60)

# %%
interp.most_confused(min_val=3)
# Out:
# [('american_pit_bull_terrier', 'staffordshire_bull_terrier', 7),
#  ('english_setter', 'english_cocker_spaniel', 7),
#  ('Birman', 'Ragdoll', 5),
#  ('Birman', 'Siamese', 4),
#  ('Egyptian_Mau', 'Bengal', 4),
#  ('boxer', 'american_bulldog', 4),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 4),
#  ('Ragdoll', 'Birman', 3),
#  ('american_bulldog', 'staffordshire_bull_terrier', 3),
#  ('beagle', 'basset_hound', 3)]

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.705361</td>
#       <td>0.371913</td>
#       <td>0.119080</td>
#       <td>01:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2,max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.233420</td>
#       <td>0.203295</td>
#       <td>0.064953</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.225469</td>
#       <td>0.204872</td>
#       <td>0.066982</td>
#       <td>01:20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ****Resnet50****

# %%
data = ImageDataBunch.from_name_re(path,fnames,pat,ds_tfms=get_transforms(),size=299,bs= bs//2).normalize(imagenet_stats)

# %%
learn = cnn_learner(data,models.resnet50,metrics=error_rate)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.720521</td>
#       <td>0.393992</td>
#       <td>0.112314</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.545514</td>
#       <td>0.330830</td>
#       <td>0.095399</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.422298</td>
#       <td>0.376382</td>
#       <td>0.105548</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.323562</td>
#       <td>0.261545</td>
#       <td>0.072395</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.252005</td>
#       <td>0.278090</td>
#       <td>0.073072</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.177632</td>
#       <td>0.249398</td>
#       <td>0.067659</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.112481</td>
#       <td>0.251012</td>
#       <td>0.069012</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.107234</td>
#       <td>0.233863</td>
#       <td>0.066982</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-50')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(3,max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.095667</td>
#       <td>0.233382</td>
#       <td>0.060893</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.126400</td>
#       <td>0.225465</td>
#       <td>0.063599</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.083201</td>
#       <td>0.213320</td>
#       <td>0.059540</td>
#       <td>01:59</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1-50');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Ragdoll', 'Birman', 8),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 7),
#  ('boxer', 'american_bulldog', 6),
#  ('Egyptian_Mau', 'Bengal', 5),
#  ('British_Shorthair', 'Russian_Blue', 4),
#  ('Siamese', 'Birman', 4),
#  ('beagle', 'basset_hound', 4),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 4),
#  ('Bengal', 'Egyptian_Mau', 3),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 3),
#  ('staffordshire_bull_terrier', 'american_bulldog', 3),
#  ('Bengal', 'British_Shorthair', 2),
#  ('British_Shorthair', 'Bombay', 2),
#  ('Maine_Coon', 'Ragdoll', 2),
#  ('Siamese', 'Bombay', 2),
#  ('american_bulldog', 'saint_bernard', 2),
#  ('american_pit_bull_terrier', 'american_bulldog', 2),
#  ('basset_hound', 'beagle', 2),
#  ('chihuahua', 'miniature_pinscher', 2)]
